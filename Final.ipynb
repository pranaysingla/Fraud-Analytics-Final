# %%
# importing libraries
import pandas as pd
import numpy as np
from datetime import timedelta
import datetime
import random

# %%
# load data
ml_df = pd.read_csv('data/ML.csv')
ml_tag = pd.read_csv('data/MLtag.csv')
synthentic_df = pd.read_csv('data/Synthetic_Financial_Datasets.csv', nrows=1_00_000)

# %%
synthentic_df.drop(['isFlaggedFraud'], axis=1, inplace=True)

# %%
synthentic_df['date'] = synthentic_df['step'].apply(lambda x: pd.to_datetime('2019-02-20') + pd.offsets.Hour(x))

# %%
mapper = {
    'type': 'typeofaction',
    'nameOrig': 'sourceid',
    'nameDest': 'destinationid',
    'amount': 'amountofmoney',
    'date': 'date',
    'isFraud': 'isfraud',
}

clean_df = synthentic_df.rename(columns = mapper)

# %%
clean_df = clean_df[mapper.values()]

# %%
clean_df['typeoffraud'] = clean_df['isfraud'].apply(lambda x: f'type{random.randint(1, 2)}' if x == 1 else 'none')

# %%
ml_df.typeofaction.replace({
    'transfer': 'TRANSFER',
    'cash-in': 'CASH_IN'
}, inplace=True)

# %%
clean_df.head()
# Out:
#   typeofaction     sourceid destinationid  amountofmoney                date  \
# 0      PAYMENT  C1231006815   M1979787155        9839.64 2019-02-20 01:00:00
# 1      PAYMENT  C1666544295   M2044282225        1864.28 2019-02-20 01:00:00
# 2     TRANSFER  C1305486145    C553264065         181.00 2019-02-20 01:00:00
# 3     CASH_OUT   C840083671     C38997010         181.00 2019-02-20 01:00:00
# 4      PAYMENT  C2048537720   M1230701703       11668.14 2019-02-20 01:00:00
#
#    isfraud typeoffraud
# 0        0        none
# 1        0        none
# 2        1       type1
# 3        1       type1
# 4        0        none

# %%
ml_df.head()
# Out:
#   typeofaction  sourceid  destinationid  amountofmoney                 date  \
# 0      CASH_IN     30105          28942         494528  2019-07-19 14:40:00
# 1      CASH_IN     30105           8692         494528  2019-05-17 14:57:00
# 2      CASH_IN     30105          60094         494528  2019-07-20 13:20:00
# 3      CASH_IN     30105          20575         494528  2019-07-03 14:15:00
# 4      CASH_IN     30105          45938         494528  2019-05-26 10:40:00
#
#    isfraud typeoffraud
# 0        1       type1
# 1        1       type1
# 2        1       type1
# 3        1       type1
# 4        1       type1

# %%
main_df = pd.concat([clean_df, ml_df], axis=0)

# %%
main_df.head()
# Out:
#   typeofaction     sourceid destinationid  amountofmoney                 date  \
# 0      PAYMENT  C1231006815   M1979787155        9839.64  2019-02-20 01:00:00
# 1      PAYMENT  C1666544295   M2044282225        1864.28  2019-02-20 01:00:00
# 2     TRANSFER  C1305486145    C553264065         181.00  2019-02-20 01:00:00
# 3     CASH_OUT   C840083671     C38997010         181.00  2019-02-20 01:00:00
# 4      PAYMENT  C2048537720   M1230701703       11668.14  2019-02-20 01:00:00
#
#    isfraud typeoffraud
# 0        0        none
# 1        0        none
# 2        1       type1
# 3        1       type1
# 4        0        none

# %%
def one_hot(df, key='typeofaction'):
    return pd.concat([
            main_df,
            pd.get_dummies(main_df[key], prefix=key, drop_first=True)
        ], axis=1)

# %%
main_df = one_hot(main_df)

# %%
main_df.drop('typeofaction', axis=1, inplace=True)
main_df.head()
# Out:
#       sourceid destinationid  amountofmoney                 date  isfraud  \
# 0  C1231006815   M1979787155        9839.64  2019-02-20 01:00:00        0
# 1  C1666544295   M2044282225        1864.28  2019-02-20 01:00:00        0
# 2  C1305486145    C553264065         181.00  2019-02-20 01:00:00        1
# 3   C840083671     C38997010         181.00  2019-02-20 01:00:00        1
# 4  C2048537720   M1230701703       11668.14  2019-02-20 01:00:00        0
#
#   typeoffraud  typeofaction_CASH_OUT  typeofaction_DEBIT  \
# 0        none                      0                   0
# 1        none                      0                   0
# 2       type1                      0                   0
# 3       type1                      1                   0
# 4        none                      0                   0
#
#    typeofaction_PAYMENT  typeofaction_TRANSFER
# 0                     1                      0
# 1                     1                      0
# 2                     0                      1
# 3                     0                      0
# 4                     1                      0

# %%
main_df = main_df.reset_index(drop=True)
main_df[['sourceid', 'destinationid']] = main_df[['sourceid', 'destinationid']].astype(str)

# %%
main_df['date'] = pd.to_datetime(main_df['date'])

# %%
main_df.to_pickle("main_df.pkl")

# %% [markdown]
# ## Start from here if you have a pickled file

# %%
main_df = pd.read_pickle('main_df.pkl')

# %%
main_df.drop('typeoffraud', axis=1, inplace=True)

# %%
# main_df = one_hot(main_df, 'sourceid')
# main_df = one_hot(main_df, 'destinationid')

# drop col
# main_df.drop(['destinationid', 'sourceid'], axis=1, inplace=True)

# %%
main_df['prefix_source'] = main_df['sourceid'].str[:1]
main_df['prefix_destination'] = main_df['destinationid'].str[:1]

# %%
main_df.head()
# Out:
#       sourceid destinationid  amountofmoney                date  isfraud  \
# 0  C1231006815   M1979787155        9839.64 2019-02-20 01:00:00        0
# 1  C1666544295   M2044282225        1864.28 2019-02-20 01:00:00        0
# 2  C1305486145    C553264065         181.00 2019-02-20 01:00:00        1
# 3   C840083671     C38997010         181.00 2019-02-20 01:00:00        1
# 4  C2048537720   M1230701703       11668.14 2019-02-20 01:00:00        0
#
#    typeofaction_CASH_OUT  typeofaction_DEBIT  typeofaction_PAYMENT  \
# 0                      0                   0                     1
# 1                      0                   0                     1
# 2                      0                   0                     0
# 3                      1                   0                     0
# 4                      0                   0                     1
#
#    typeofaction_TRANSFER prefix_source prefix_destination
# 0                      0             C                  M
# 1                      0             C                  M
# 2                      1             C                  C
# 3                      0             C                  C
# 4                      0             C                  M

# %%
def create_datetime_features(df, col, time_params_reqd = False, remove_main_date=False, prefix='temp'):
    """
    Function to extract features from the datetime column and return the df with the updated values

    Example:
    create_datetime_features(portfoliostats[['BookedDate']], 'BookedDate', prefix='bookedDate', remove_main_date=True)
    """
    if df[col].dtype != 'datetime64[ns]':
        df[col] = pd.to_datetime(df[col]) 
        
    df[f'{prefix}_year'] = df[col].dt.year
    df[f'{prefix}_month'] = df[col].dt.month
    df[f'{prefix}_day'] = df[col].dt.day
    df[f'{prefix}_week'] = df[col].dt.week
    df[f'{prefix}_dayofweek'] = df[col].dt.dayofweek
    df[f'{prefix}_isweekend'] = (df[col].dt.dayofweek >=5).astype(int)
    df[f'{prefix}_isWeekday'] = (df[col].dt.dayofweek < 5).astype(int)
    df[f'{prefix}_dayofyear'] = df[col].dt.dayofyear
    df[f'{prefix}_quarter'] = df[col].dt.quarter
    df[f'{prefix}_isleapyear'] = df[col].dt.is_leap_year.astype(int)
    df[f'{prefix}_monthDifferenceFromToday'] = (datetime.datetime.today() - df[col]).dt.days//30
    df[f'{prefix}_dayDifferenceFromToday'] = (datetime.datetime.today() - df[col]).dt.days

    if time_params_reqd:
        df[f'{prefix}_hour'] = df[col].dt.hour
        df[f'{prefix}_minute'] = df[col].dt.minute

    if remove_main_date:
        df.drop([col], axis=1, inplace=True)
    
    return df

# %%
main_df = main_df.sort_values('date')

# %%
main_df['date_lag'] = main_df.groupby('sourceid')['date'].shift(-1)
main_df['date_lag'].fillna(pd.to_datetime('2019-02-13'), inplace=True)
main_df['days_since_last_transaction'] = (main_df['date'] - main_df['date_lag']).dt.days
main_df['hours_since_last_transaction'] = (main_df['date'] - main_df['date_lag']).dt.components['hours']
main_df['mins_since_last_transaction'] = (main_df['date'] - main_df['date_lag']).dt.components['minutes']

# %%
main_df = create_datetime_features(main_df, 'date', True, False)
# Out:
# /Users/pansul/Documents/time-series/time-series-final-project/venv/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
main_df.head()
# Out:
#          sourceid destinationid  amountofmoney                date  isfraud  \
# 0     C1231006815   M1979787155        9839.64 2019-02-20 01:00:00        0
# 1801  C1562950869   M2021835850        5157.05 2019-02-20 01:00:00        0
# 1802   C845388562    M550572371        5746.44 2019-02-20 01:00:00        0
# 1803   C948424584   M1447685190        5607.36 2019-02-20 01:00:00        0
# 1804  C2027701910   M1345293143        6360.79 2019-02-20 01:00:00        0
#
#       typeofaction_CASH_OUT  typeofaction_DEBIT  typeofaction_PAYMENT  \
# 0                         0                   0                     1
# 1801                      0                   0                     1
# 1802                      0                   0                     1
# 1803                      0                   0                     1
# 1804                      0                   0                     1
#
#       typeofaction_TRANSFER prefix_source  ... temp_dayofweek temp_isweekend  \
# 0                         0             C  ...              2              0
# 1801                      0             C  ...              2              0
# 1802                      0             C  ...              2              0
# 1803                      0             C  ...              2              0
# 1804                      0             C  ...              2              0
#
#       temp_isWeekday  temp_dayofyear  temp_quarter  temp_isleapyear  \
# 0                  1              51             1                0
# 1801               1              51             1                0
# 1802               1              51             1                0
# 1803               1              51             1                0
# 1804               1              51             1                0
#
#       temp_monthDifferenceFromToday  temp_dayDifferenceFromToday  temp_hour  \
# 0                                20                          618          1
# 1801                             20                          618          1
# 1802                             20                          618          1
# 1803                             20                          618          1
# 1804                             20                          618          1
#
#       temp_minute
# 0               0
# 1801            0
# 1802            0
# 1803            0
# 1804            0
#
# [5 rows x 29 columns]

# %%
main_df.drop(['destinationid', 'sourceid', 'date'], axis=1, inplace=True, errors='ignore')

# %%
pd.options.display.max_columns = None

# %%
main_df.head()
# Out:
#       amountofmoney  isfraud  typeofaction_CASH_OUT  typeofaction_DEBIT  \
# 0           9839.64        0                      0                   0
# 1801        5157.05        0                      0                   0
# 1802        5746.44        0                      0                   0
# 1803        5607.36        0                      0                   0
# 1804        6360.79        0                      0                   0
#
#       typeofaction_PAYMENT  typeofaction_TRANSFER prefix_source  \
# 0                        1                      0             C
# 1801                     1                      0             C
# 1802                     1                      0             C
# 1803                     1                      0             C
# 1804                     1                      0             C
#
#      prefix_destination   date_lag  days_since_last_transaction  \
# 0                     M 2019-02-13                            7
# 1801                  M 2019-02-13                            7
# 1802                  M 2019-02-13                            7
# 1803                  M 2019-02-13                            7
# 1804                  M 2019-02-13                            7
#
#       hours_since_last_transaction  mins_since_last_transaction  temp_year  \
# 0                                1                            0       2019
# 1801                             1                            0       2019
# 1802                             1                            0       2019
# 1803                             1                            0       2019
# 1804                             1                            0       2019
#
#       temp_month  temp_day  temp_week  temp_dayofweek  temp_isweekend  \
# 0              2        20          8               2               0
# 1801           2        20          8               2               0
# 1802           2        20          8               2               0
# 1803           2        20          8               2               0
# 1804           2        20          8               2               0
#
#       temp_isWeekday  temp_dayofyear  temp_quarter  temp_isleapyear  \
# 0                  1              51             1                0
# 1801               1              51             1                0
# 1802               1              51             1                0
# 1803               1              51             1                0
# 1804               1              51             1                0
#
#       temp_monthDifferenceFromToday  temp_dayDifferenceFromToday  temp_hour  \
# 0                                20                          618          1
# 1801                             20                          618          1
# 1802                             20                          618          1
# 1803                             20                          618          1
# 1804                             20                          618          1
#
#       temp_minute
# 0               0
# 1801            0
# 1802            0
# 1803            0
# 1804            0
